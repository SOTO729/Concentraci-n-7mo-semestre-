# %% [markdown]
# #Datos a trabajar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
country.head()
# Out:
#              Name      Continent                     Region  IndepYear  \
# Code
# ABW         Aruba  North America                  Caribbean        NaN
# AFG   Afghanistan           Asia  Southern and Central Asia     1919.0
# AGO        Angola         Africa             Central Africa     1975.0
# AIA      Anguilla  North America                  Caribbean        NaN
# ALB       Albania         Europe            Southern Europe     1912.0
#
#       Population  LifeExpectancy     GNP  Capital
# Code
# ABW       103000            78.4   828.0    129.0
# AFG     22720000            45.9  5976.0      1.0
# AGO     12878000            38.3  6648.0     56.0
# AIA         8000            76.1    63.2     62.0
# ALB      3401200            71.6  3205.0     34.0

# %%
import pandas as pd
from pandas import DataFrame

city=pd.read_csv('CITY.csv', index_col='ID')
language=pd.read_csv('LANGUAGE.csv')
country=pd.read_csv('COUNTRY.csv', index_col='Code')
country=country.drop(['GovernmentForm','LocalName','GNPOld','SurfaceArea'], axis=1)
city.head(3)
# Out:
#         Name CountryCode  District  Population
# ID
# 1      Kabul         AFG     Kabol     1780000
# 2   Qandahar         AFG  Qandahar      237500
# 3      Herat         AFG     Herat      186800

# %%
# Out:
# 3263.0

# %%
pais=input('Inserte el pais...')
city[city.index==country[country['Name']==pais]['Capital'].values[0]]['Name'].values[0]
# Out:
# Inserte el pais...Taiwan
# 'Taipei'

# %%
pais=input('Inserte el pais...')
codigo_pais=country[country['Name']==pais]['Capital'].values[0]
ciudad=city[city.index==codigo_pais]['Name'].values[0]
ciudad
# Out:
# Inserte el pais...Taiwan
# 'Taipei'

# %%
language.head(3)
# Out:
#   CountryCode    Language IsOfficial  Percentage
# 0         ABW       Dutch          T         5.3
# 1         ABW     English          F         9.5
# 2         ABW  Papiamento          F        76.7

# %%
country.head(3)
# Out:
#              Name      Continent                     Region  IndepYear  \
# Code
# ABW         Aruba  North America                  Caribbean        NaN
# AFG   Afghanistan           Asia  Southern and Central Asia     1919.0
# AGO        Angola         Africa             Central Africa     1975.0
#
#       Population  LifeExpectancy     GNP  Capital
# Code
# ABW       103000            78.4   828.0    129.0
# AFG     22720000            45.9  5976.0      1.0
# AGO     12878000            38.3  6648.0     56.0

# %% [markdown]
# #Consultas

# %% [markdown]
# Nombre del país con la clae "AFG"

# %%
country.loc['AFG','Name']
# Out:
# 'Afghanistan'

# %% [markdown]
# Lenguajes que se hablan en el pais con el código 'AGO'

# %%
language[language['CountryCode']=='AGO']['Language']
# Out:
# 9                 Ambo
# 10              Chokwe
# 11               Kongo
# 12             Luchazi
# 13    Luimbe-nganguela
# 14              Luvale
# 15              Mbundu
# 16     Nyaneka-nkhumbi
# 17           Ovimbundu
# Name: Language, dtype: object

# %%
country[country['Name']=='Mexico'].index[0]
# Out:
# 'MEX'

# %%
#Lenguajes que se hablan en mexico
language[language['CountryCode']==country[country['Name']=='Mexico'].index[0]]['Language']
# Out:
# 545     Mixtec
# 546    Náhuatl
# 547      Otomí
# 548    Spanish
# 549    Yucatec
# 550    Zapotec
# Name: Language, dtype: object

# %%
language[(language['CountryCode']==country[country['Name']=='Mexico'].index[0])&(language['IsOfficial']=='T')]['Language'].values[0]
# Out:
# 'Spanish'

# %% [markdown]
# Nombre de los paises de América del norte que tienen esperanza de vida mayor a 75 años

# %% [markdown]
# Imprimir la lengua oficial de México

# %% [markdown]
# Capital de Taiwan

# %% [markdown]
# Continente donde se encuetra la ciudad más poblada

# %%
country.head()
# Out:
#              Name      Continent                     Region  IndepYear  \
# Code
# ABW         Aruba  North America                  Caribbean        NaN
# AFG   Afghanistan           Asia  Southern and Central Asia     1919.0
# AGO        Angola         Africa             Central Africa     1975.0
# AIA      Anguilla  North America                  Caribbean        NaN
# ALB       Albania         Europe            Southern Europe     1912.0
#
#       Population  LifeExpectancy     GNP  Capital
# Code
# ABW       103000            78.4   828.0    129.0
# AFG     22720000            45.9  5976.0      1.0
# AGO     12878000            38.3  6648.0     56.0
# AIA         8000            76.1    63.2     62.0
# ALB      3401200            71.6  3205.0     34.0

# %%
country[country['Capital']==float(city[['Name','Population']][city['Population']==city['Population'].max()].index[0])]
# Out:
# Empty DataFrame
# Columns: [Name, Continent, Region, IndepYear, Population, LifeExpectancy, GNP, Capital]
# Index: []

# %%
city.head()
# Out:
#               Name CountryCode       District  Population
# ID
# 1            Kabul         AFG          Kabol     1780000
# 2         Qandahar         AFG       Qandahar      237500
# 3            Herat         AFG          Herat      186800
# 4   Mazar-e-Sharif         AFG          Balkh      127800
# 5        Amsterdam         NLD  Noord-Holland      731200

# %%
code_pais=city[city['Population']==city['Population'].max()]['CountryCode'].values[0]

# %%
country[country.index==code_pais]['Continent'].values[0]
# Out:
# 'Asia'

# %% [markdown]
# Lista de continentes

# %%
country[country.index.isin(language[(language['Language']=='Spanish') & (language['IsOfficial']=='T')]['CountryCode'])]['Name'].values
# Out:
# array(['Argentina', 'Bolivia', 'Chile', 'Colombia', 'Costa Rica', 'Cuba',
#        'Dominican Republic', 'Ecuador', 'Spain', 'Guatemala', 'Honduras',
#        'Mexico', 'Nicaragua', 'Panama', 'Peru', 'Puerto Rico', 'Paraguay',
#        'El Salvador', 'Uruguay', 'Venezuela'], dtype=object)

# %%
paises=language[(language['Language']=='Spanish') & (language['IsOfficial']=='T')]['CountryCode']
country[country.index.isin(paises)]['Name'].values
# Out:
# array(['Argentina', 'Bolivia', 'Chile', 'Colombia', 'Costa Rica', 'Cuba',
#        'Dominican Republic', 'Ecuador', 'Spain', 'Guatemala', 'Honduras',
#        'Mexico', 'Nicaragua', 'Panama', 'Peru', 'Puerto Rico', 'Paraguay',
#        'El Salvador', 'Uruguay', 'Venezuela'], dtype=object)

# %%
country.loc[paises,'Name'].values
# Out:
# array(['Argentina', 'Bolivia', 'Chile', 'Colombia', 'Costa Rica', 'Cuba',
#        'Dominican Republic', 'Ecuador', 'Spain', 'Guatemala', 'Honduras',
#        'Mexico', 'Nicaragua', 'Panama', 'Peru', 'Puerto Rico', 'Paraguay',
#        'El Salvador', 'Uruguay', 'Venezuela'], dtype=object)

# %% [markdown]
# Ciudades de méxico con más de 1000000 habitantes
#
# 1.   List item
# 2.   List item

# %% [markdown]
# Poblacion de Querétaro y Puebla

# %% [markdown]
# Paises donde el español es la lengua oficial

# %%
# %%shell
# jupyter nbconvert --to html 3_3_2_EjerciciosConsultas.ipynb
